# %%
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

data_set = pd.read_csv("3_taxi_peru.csv", sep = ';')
data_set
# Out:
#                              journey_id                           user_id  \
# 0      23a1406fc6a11d866e3c82f22eed4d4c  0e9af5bbf1edfe591b54ecdfd7e91e26
# 1      dd2af4715d0dc16eded53afc0e243577  a553c46e3a22fb9c326aeb3d72b3334e
# 2      dd91e131888064bf7df3ce08f3d4b4ad  a553c46e3a22fb9c326aeb3d72b3334e
# 3      dd2af4715d0dc16eded53afc0e2466d0  a553c46e3a22fb9c326aeb3d72b3334e
# 4      85b7eabcf5d84e42dc7629b7d27781af  56772d544fdfa589a020a1ff894a86f7
# ...                                 ...                               ...
# 23106  4a18ea5737ce0ffecaf20b305a0e2c86  8998bb370b5f0cec43a373adebba0c72
# 23107  f1e4317f2c17991dd90d1cd17ae0d399  5f8a6ffef0ea5df78a8ee890267b60ec
# 23108  1e44c0fd0a266c3719ff30410b257bce  c0ffb6f6cd801004dd8609c12277c2d1
# 23109  7073883383b89ad289e864022150cdd7  c0ffb6f6cd801004dd8609c12277c2d1
# 23110  b7dea45c3cc92b9efd5a4905e69ff9bf  c0ffb6f6cd801004dd8609c12277c2d1
#
#                               driver_id                           taxi_id  \
# ...

# %%
data_set.info
# Out:
# <bound method DataFrame.info of                              journey_id                           user_id  \
# 0      23a1406fc6a11d866e3c82f22eed4d4c  0e9af5bbf1edfe591b54ecdfd7e91e26
# 1      dd2af4715d0dc16eded53afc0e243577  a553c46e3a22fb9c326aeb3d72b3334e
# 2      dd91e131888064bf7df3ce08f3d4b4ad  a553c46e3a22fb9c326aeb3d72b3334e
# 3      dd2af4715d0dc16eded53afc0e2466d0  a553c46e3a22fb9c326aeb3d72b3334e
# 4      85b7eabcf5d84e42dc7629b7d27781af  56772d544fdfa589a020a1ff894a86f7
# ...                                 ...                               ...
# 23106  4a18ea5737ce0ffecaf20b305a0e2c86  8998bb370b5f0cec43a373adebba0c72
# 23107  f1e4317f2c17991dd90d1cd17ae0d399  5f8a6ffef0ea5df78a8ee890267b60ec
# 23108  1e44c0fd0a266c3719ff30410b257bce  c0ffb6f6cd801004dd8609c12277c2d1
# 23109  7073883383b89ad289e864022150cdd7  c0ffb6f6cd801004dd8609c12277c2d1
# 23110  b7dea45c3cc92b9efd5a4905e69ff9bf  c0ffb6f6cd801004dd8609c12277c2d1
#
# ...

# %%
data_set.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23111 entries, 0 to 23110
# Data columns (total 19 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   journey_id        23111 non-null  object
#  1   user_id           23111 non-null  object
#  2   driver_id         19726 non-null  object
#  3   taxi_id           19726 non-null  object
#  4   icon              23111 non-null  object
#  5   start_type        23111 non-null  object
#  6   start_at          23111 non-null  object
#  7   start_lat         23111 non-null  object
#  8   start_lon         23111 non-null  object
#  9   end_at            22835 non-null  object
#  10  end_lat           23111 non-null  object
#  11  end_lon           23111 non-null  object
#  12  end_state         23099 non-null  object
#  13  driver_start_lat  19621 non-null  object
#  14  driver_start_lon  19621 non-null  object
#  15  arrived_at        17716 non-null  object
# ...

# %%
data_set = pd.read_csv("3_taxi_peru.csv", sep = ';', parse_dates = ["start_at", "end_at", "arrived_at"])

# %%
data_set.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23111 entries, 0 to 23110
# Data columns (total 19 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   journey_id        23111 non-null  object
#  1   user_id           23111 non-null  object
#  2   driver_id         19726 non-null  object
#  3   taxi_id           19726 non-null  object
#  4   icon              23111 non-null  object
#  5   start_type        23111 non-null  object
#  6   start_at          23111 non-null  datetime64[ns]
#  7   start_lat         23111 non-null  object
#  8   start_lon         23111 non-null  object
#  9   end_at            22835 non-null  datetime64[ns]
#  10  end_lat           23111 non-null  object
#  11  end_lon           23111 non-null  object
#  12  end_state         23099 non-null  object
#  13  driver_start_lat  19621 non-null  object
#  14  driver_start_lon  19621 non-null  object
# ...

# %%
data_set.describe()
# Out:
#        driver_score   rider_score
# count   7650.000000  15390.000000
# mean       3.933333      4.755491
# std        1.744948      0.840558
# min        0.000000      0.000000
# 25%        4.000000      5.000000
# 50%        5.000000      5.000000
# 75%        5.000000      5.000000
# max        5.000000      5.000000

# %%
data_set.source.value_counts(normalize=True).mul(100).round(2)
# Out:
# iPhone     42.37
# web        33.20
# Android    21.35
# iPad        2.48
# Wap         0.59
# Name: source, dtype: float64

# %%
data_set.source.value_counts().plot()
# Out:
# <AxesSubplot: >

# %%
data_set.source.value_counts().plot.bar()
# Out:
# <AxesSubplot: >

# %%
data = data_set.source.value_counts().to_frame()

# %%
data
# Out:
#          source
# iPhone     9741
# web        7631
# Android    4909
# iPad        571
# Wap         136

# %%
data = data_set.source.value_counts().reset_index()
data
# Out:
#      index  source
# 0   iPhone    9741
# 1      web    7631
# 2  Android    4909
# 3     iPad     571
# 4      Wap     136

# %%
sns.barplot(data=data, x='index', y="source")
# Out:
# <AxesSubplot: xlabel='index', ylabel='source'>

# %%
plt.figure(figsize=(12,8))
sns.countplot(data_set['source'],x=data_set.source,  hue=data_set['end_state'])

# %%
plt.figure(figsize=(12,8))
sns.set_theme()
sns.countplot(data_set['source'],x=data_set.source,  hue=data_set['end_state'], palette='hls')
plt.show()

# %%
sns.countplot(data_set['source'],x=data_set.driver_score,  hue=data_set['end_state'])
# Out:
# <AxesSubplot: xlabel='driver_score', ylabel='count'>

# %%
sns.countplot(data_set['source'],x=data_set.driver_score,  hue=data_set['source'])
# Out:
# <AxesSubplot: xlabel='driver_score', ylabel='count'>

# %%
plt.figure(figsize=(12,8))
sns.countplot(data_set['source'],x=data_set.driver_score,  hue=data_set['source'])
# Out:
# <AxesSubplot: xlabel='driver_score', ylabel='count'>

# %%
plt.figure(figsize=(12,8))
sns.countplot(data_set['source'],x=data_set.rider_score,  hue=data_set['source'])
# Out:
# <AxesSubplot: xlabel='rider_score', ylabel='count'>

# %%
sns.heatmap(data_set.corr())
# Out:
# C:\Users\sivvi\AppData\Local\Temp\ipykernel_18504\106431116.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(data_set.corr())
# <AxesSubplot: >
